# %%
import pandas as pd
from prophet import Prophet
from matplotlib import pyplot as plt
plt.figure(figsize=(10,10))

# %%
data = pd.read_feather('tavbase/gs.feather')
data
# Out:
#              Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0      MX-2014-143658 2014-10-02 2014-10-06  Standard Class    SC-20575
# 1      MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 2      MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 3      MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# 4      MX-2012-155047 2012-10-15 2012-10-20  Standard Class    KW-16570
# ...               ...        ...        ...             ...         ...
# 51285    HU-2012-7730 2012-09-05 2012-09-07     First Class     NF-8385
# 51286    HU-2012-7730 2012-09-05 2012-09-07     First Class     NF-8385
# 51287    HU-2012-7730 2012-09-05 2012-09-07     First Class     NF-8385
# 51288    HU-2012-7730 2012-09-05 2012-09-07     First Class     NF-8385
# 51289    IZ-2011-5750 2011-08-25 2011-08-29  Standard Class    SZ-10035
#
#           Customer Name      Segment           City             State  \
# 0          Sonia Cooley     Consumer    Mexico City  Distrito Federal
# 1        Kelly Williams     Consumer  Dos Quebradas         Risaralda
# 2        Kelly Williams     Consumer  Dos Quebradas         Risaralda
# 3        Kelly Williams     Consumer  Dos Quebradas         Risaralda
# 4        Kelly Williams     Consumer  Dos Quebradas         Risaralda
# ...                 ...          ...            ...               ...
# 51285  Natalie Fritzler     Consumer       Budapest          Budapest
# 51286  Natalie Fritzler     Consumer       Budapest          Budapest
# 51287  Natalie Fritzler     Consumer       Budapest          Budapest
# 51288  Natalie Fritzler     Consumer       Budapest          Budapest
# 51289        Sam Zeldin  Home Office        Baghdad           Baghdad
#
#         Country  ... Profit Shipping Cost Order Priority  Year Month Period  \
# 0        Mexico  ...   4.56         1.033         Medium  2014    10     46
# 1      Colombia  ...  90.72        13.449         Medium  2012    10     22
# 2      Colombia  ...  54.08         9.627         Medium  2012    10     22
# 3      Colombia  ...   4.96         1.371         Medium  2012    10     22
# 4      Colombia  ...  11.44         3.787         Medium  2012    10     22
# ...         ...  ...    ...           ...            ...   ...   ...    ...
# 51285   Hungary  ...   3.42         1.980           High  2012     9     21
# 51286   Hungary  ...  18.42        13.020           High  2012     9     21
# 51287   Hungary  ...  20.88         8.780           High  2012     9     21
# 51288   Hungary  ...  33.84        18.970           High  2012     9     21
# 51289      Iraq  ...  12.96         2.400         Medium  2011     8      8
#
#        Order Date Month  Delivery  Price  Benefit
# 0            2014-10-01         4   4.36        1
# 1            2012-10-01         5  31.52        1
# 2            2012-10-01         5  96.64        1
# 3            2012-10-01         5   8.86        1
# 4            2012-10-01         5  35.80        1
# ...                 ...       ...    ...      ...
# 51285        2012-09-01         2  11.07        1
# 51286        2012-09-01         2  30.72        1
# 51287        2012-09-01         2  20.13        1
# 51288        2012-09-01         2  32.61        1
# 51289        2011-08-01         4  31.62        1
#
# [51290 rows x 29 columns]

# %%
## Aula 10 - Regressão (com sazonalidades)
regressao_market = pd.DataFrame()
for market in data['Market'].unique():
    regressao = data[data['Market'] == market][
        ['Order Date Month', 'Sales']
    ].groupby('Order Date Month')['Sales'].sum().reset_index()
    regressao = regressao.rename(columns={
        'Order Date Month': 'ds', 'Sales': 'y'
    })
    m = Prophet().fit(regressao)
    future = m.make_future_dataframe(periods=12, freq='MS')
    forecast = m.predict(future)
    forecast['Market'] = market
    fig1 = m.plot(forecast)
    plt.show()
    regressao_market = regressao_market.append(
        forecast[['Market', 'ds', 'yhat', 'yhat_lower', 'yhat_upper']],
        ignore_index = True
    )
regressao_market
# Out:
# 23:23:17 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:17 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/1748332380.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_market = regressao_market.append(
# 23:23:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:18 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/1748332380.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_market = regressao_market.append(
# 23:23:19 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:19 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/1748332380.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_market = regressao_market.append(
# 23:23:20 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:20 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/1748332380.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_market = regressao_market.append(
# 23:23:21 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:21 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/1748332380.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_market = regressao_market.append(
# 23:23:22 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:23 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/1748332380.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_market = regressao_market.append(
# 23:23:24 - cmdstanpy - INFO - Chain [1] start processing
# 23:23:24 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/1748332380.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_market = regressao_market.append(
#      Market         ds          yhat    yhat_lower    yhat_upper
# 0     LATAM 2011-01-01   7070.056736  -2482.620215  16165.476124
# 1     LATAM 2011-02-01   1597.761500  -7142.097413  10698.952848
# 2     LATAM 2011-03-01  16738.231652   8240.413775  25455.170444
# 3     LATAM 2011-04-01  15623.035671   6189.426551  23894.858727
# 4     LATAM 2011-05-01  23615.807581  15143.606599  32416.757041
# ..      ...        ...           ...           ...           ...
# 414  Canada 2015-08-01   3302.438715   1812.710511   4702.837121
# 415  Canada 2015-09-01   2578.983705   1178.057686   4032.696796
# 416  Canada 2015-10-01   2383.202909   1014.798628   3879.410663
# 417  Canada 2015-11-01   2978.114609   1751.239258   4350.242870
# 418  Canada 2015-12-01   3548.533598   2243.241020   5019.818518
#
# [419 rows x 5 columns]

# %%
regressao_market.to_feather('tavbase/regressao_mercado.feather')

# %%
regressao_region = pd.DataFrame()
for region in data['Region'].unique():
    regressao = data[data['Region'] == region][
        ['Order Date Month', 'Sales']
    ].groupby('Order Date Month')['Sales'].sum().reset_index()
    regressao = regressao.rename(columns={
        'Order Date Month': 'ds', 'Sales': 'y'
    })
    m = Prophet().fit(regressao)
    future = m.make_future_dataframe(periods=12, freq='MS')
    forecast = m.predict(future)
    forecast['Region'] = region
    fig1 = m.plot(forecast)
    plt.show()
    regressao_region = regressao_region.append(
        forecast[['Region', 'ds', 'yhat', 'yhat_lower', 'yhat_upper']],
        ignore_index = True
    )
regressao_region
# Out:
# 23:26:07 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:08 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:09 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:09 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:11 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:11 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:13 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:13 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:14 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:14 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:16 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:16 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:17 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:17 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:18 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:19 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:20 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:20 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:21 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:22 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:22 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:23 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:24 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:25 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
# 23:26:26 - cmdstanpy - INFO - Chain [1] start processing
# 23:26:26 - cmdstanpy - INFO - Chain [1] done processing
# /tmp/ipykernel_4300/281339669.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   regressao_region = regressao_region.append(
#      Region         ds          yhat   yhat_lower    yhat_upper
# 0     North 2011-01-01   9412.949836  3863.230910  14939.375250
# 1     North 2011-02-01   4248.405659 -1513.605410  10079.374938
# 2     North 2011-03-01  12299.283979  6543.133651  18052.433576
# 3     North 2011-04-01   7299.836807  1431.107322  13016.422672
# 4     North 2011-05-01   9745.802121  3937.444621  15637.716439
# ..      ...        ...           ...          ...           ...
# 774  Canada 2015-08-01   3302.438715  1845.689707   4716.052865
# 775  Canada 2015-09-01   2578.983705  1250.346396   3897.595007
# 776  Canada 2015-10-01   2383.202909  1042.630232   3781.413497
# 777  Canada 2015-11-01   2978.114609  1614.080271   4365.131143
# 778  Canada 2015-12-01   3548.533598  2187.052734   4999.188382
#
# [779 rows x 5 columns]

# %%
regressao_region.to_feather('tavbase/regressao_regiao.feather')
